# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

survey = pd.read_csv("/kaggle/input/2021-new-coder-survey/2021 New Coder Survey.csv")

# %%
survey.head()
# Out:
#            Timestamp 1. What is your biggest reason for learning to code?  \
# 0  7/1/2021 10:10:23                       To succeed in current career
# 1  7/1/2021 10:31:01                                  To change careers
# 2  7/1/2021 10:42:31                                  To change careers
# 3  7/1/2021 11:06:43                                         As a hobby
# 4  7/1/2021 11:14:31                         To start your first career
#
#   2. What methods have you used to learn about coding? Please select all that apply.  \
# 0  Online resources, Books, In-person bootcamps, ...
# 1          Online resources, Books, Online bootcamps
# 2  Online resources, Books, Hackathons, Meetup.co...
# 3                            Online resources, Books
# 4          Online resources, Books, Online bootcamps
#
#   3. Which online learning resources have you found helpful? Please select all that apply.  \
# 0  freeCodeCamp, Mozilla Developer Network (MDN),...
# ...

# %%
survey.columns
# Out:
# Index(['Timestamp', '1. What is your biggest reason for learning to code?',
#        '2. What methods have you used to learn about coding? Please select all that apply.',
#        '3. Which online learning resources have you found helpful? Please select all that apply.',
#        '4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.',
#        '5. If you have listened to coding-related podcasts before, which ones have you found helpful? Please select all that apply.',
#        '6. If you have watched coding-related YouTube videos before, which channels have you found helpful? Please select all that apply.',
#        '7. About how many hours do you spend learning each week?',
#        '8. About how many months have you been programming?',
#        '9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?',
# ...

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18126 entries, 0 to 18125
# Data columns (total 63 columns):
#  #   Column                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                      --------------  -----
#  0   Timestamp                                                                                                                                                                   18126 non-null  object
#  1   1. What is your biggest reason for learning to code?                                                                                                                        17991 non-null  object
# ...

# %%
survey.keys()
# Out:
# Index(['Timestamp', '1. What is your biggest reason for learning to code?',
#        '2. What methods have you used to learn about coding? Please select all that apply.',
#        '3. Which online learning resources have you found helpful? Please select all that apply.',
#        '4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.',
#        '5. If you have listened to coding-related podcasts before, which ones have you found helpful? Please select all that apply.',
#        '6. If you have watched coding-related YouTube videos before, which channels have you found helpful? Please select all that apply.',
#        '7. About how many hours do you spend learning each week?',
#        '8. About how many months have you been programming?',
#        '9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?',
# ...

# %%
df = pd.DataFrame()
df['Developer'] = survey.iloc[:,10]
df['Age'] = survey.iloc[:,23] 
df['Gender'] = survey.iloc[:,24]
df['Area'] = survey.iloc[:,26] 
df['Immigrant'] = survey.iloc[:,29]
df['English'] = survey.iloc[:,31]
df['Education'] = survey.iloc[:,32] 
df['Income'] = survey.iloc[:,22]   

df.head()
# Out:
#   Developer   Age             Gender                         Area Immigrant  \
# 0       Yes  33.0  Prefer not to say      Europe and Central Asia        No
# 1        No  38.0               Male  Latin America and Caribbean        No
# 2        No   NaN               Male                North America        No
# 3        No  19.0               Male           Sub-Saharan Africa        No
# 4       Yes  35.0               Male        East Asia and Pacific        No
#
#   English                                Education              Income
# 0     Yes  Professional degree (MBA, MD, JD, etc.)                 NaN
# 1     Yes                        Bachelor’s degree        Under $1,000
# 2      No       Master's degree (non-professional)                 NaN
# 3      No  High school diploma or equivalent (GED)                 NaN
# 4     Yes                        Bachelor’s degree  $40,000 to $49,999

# %%
missing=round((df.isnull().sum()/df.shape[0])*100,2)
print(missing)
# Out:
# Developer     2.50
# Age           5.64
# Gender        3.66
# Area          4.92
# Immigrant     5.48
# English       4.04
# Education     5.08
# Income       44.02
# dtype: float64

# %%
df["Developer"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df["Age"].unique()
# Out:
# array([ 33. ,  38. ,   nan,  19. ,  35. ,  27. ,  24. ,  23. ,  50. ,
#         26. ,  44. ,  25. ,  21. ,  20. ,  22. ,  29. ,  46. ,  28. ,
#         37. ,  39. ,  30. ,  31. ,  15. ,  32. ,  40. ,  45. ,  36. ,
#         47. ,  41. ,  13. ,  49. , 100. ,  34. ,  18. ,  16. ,  42. ,
#         14. ,  55. ,  17. ,  56. ,  63. ,  57. ,  59. ,  75. ,  43. ,
#         48. ,  60. ,  53. ,  66. ,  52. ,  65. ,  54. ,  51. ,  62. ,
#         77. ,  12. ,  61. ,  11. ,  70. ,   6. ,  10. ,  58. ,  99. ,
#         69. ,  76. ,  64. ,   7. ,  72. ,  71. ,  83. ,   8.5,  19.5,
#         16.5,  74. ,  67. ,  73. ,  68. ,  80. ,   8. ,  78. ,   9. ,
#         95. ,  16.7,  89. ,  79. , 120. ,  82. ,  84. ,  15.5,  14.5,
#         88. ])

# %%
df["Gender"].unique()
# Out:
# array(['Prefer not to say', 'Male', nan, 'Female', 'Nonbinary',
#        'Nonbinary woman', 'Both', 'Queer', 'Gay',
#        "Physically female, but I don't relate to that (or any gender) as an identity",
#        'trans', 'Trans male', 'human', '18', 'Traditional Male',
#        'Trans guy', 'Athlet', 'Human', 'Male, He/They/Them',
#        'Living being ', 'I am a meat popsicle',
#        'I see myself as a person who is not restricted not limited by my gender as a female in being the best that I can be per time being blessed and being a blessing (problem solver/solution provider)',
#        'Transmale', 'Transmasculine Genderqueer', 'Nonbinary girl',
#        'FTM Trans',
#        'Assigned male at birth.  Female.  I am a trans woman.',
#        'genderfluid or demigirl', 'Diverse and flexible', 'He/Him',
#        'Male teen', 'PINEAPPLE (rpz le meilleur sex)', 'Agender',
#        'transgender', 'Mixed', 'Gamer', 'trans man', 'Gaki jk (male) ',
# ...

# %%
df['Age']=round(df['Age'])
df['Age'].unique()
# Out:
# array([ 33.,  38.,  nan,  19.,  35.,  27.,  24.,  23.,  50.,  26.,  44.,
#         25.,  21.,  20.,  22.,  29.,  46.,  28.,  37.,  39.,  30.,  31.,
#         15.,  32.,  40.,  45.,  36.,  47.,  41.,  13.,  49., 100.,  34.,
#         18.,  16.,  42.,  14.,  55.,  17.,  56.,  63.,  57.,  59.,  75.,
#         43.,  48.,  60.,  53.,  66.,  52.,  65.,  54.,  51.,  62.,  77.,
#         12.,  61.,  11.,  70.,   6.,  10.,  58.,  99.,  69.,  76.,  64.,
#          7.,  72.,  71.,  83.,   8.,  74.,  67.,  73.,  68.,  80.,  78.,
#          9.,  95.,  89.,  79., 120.,  82.,  84.,  88.])

# %%
df.drop(df[(df["Gender"] != 'Male') & (df["Gender"] != 'Female')].index, inplace=True)

print(df["Gender"].unique())
# Out:
# ['Male' 'Female']

# %%
df["Area"].unique()
# Out:
# array(['Latin America and Caribbean', 'North America',
#        'Sub-Saharan Africa', 'East Asia and Pacific',
#        'Europe and Central Asia', 'South Asia', 'Southeast Asia',
#        'Middle East and North Africa', nan], dtype=object)

# %%
df["Immigrant"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["English"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df["Education"].unique()
# Out:
# array(['Bachelor’s degree', "Master's degree (non-professional)",
#        'High school diploma or equivalent (GED)',
#        'Some college credit, no degree',
#        'Professional degree (MBA, MD, JD, etc.)', 'Associate’s degree',
#        'Trade, technical, or vocational training',
#        'No high school (secondary school)', 'Some high school', nan,
#        'Ph.D.'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16702 entries, 1 to 18125
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Developer  16519 non-null  object
#  1   Age        16335 non-null  float64
#  2   Gender     16702 non-null  object
#  3   Area       16417 non-null  object
#  4   Immigrant  16319 non-null  object
#  5   English    16534 non-null  object
#  6   Education  16375 non-null  object
#  7   Income     9710 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 1.1+ MB

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)

num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :',num_col)
# Out:
# Categorical columns : ['Developer', 'Gender', 'Area', 'Immigrant', 'English', 'Education', 'Income']
# Numerical columns : ['Age']

# %%
df_clean = df.dropna()
print(df_clean['Income'].unique())
# Out:
# ['Under $1,000' '$40,000 to $49,999' '$75,000 to $89,999'
#  '$60,000 to $74,999' '$1,000 to $2,999' '$10,000 to $14,999'
#  '$20,000 to $24,999' '$25,000 to $29,999' '$30,000 to $34,999'
#  '$3,000 to $4,999' '$50,000 to $59,999' '$15,000 to $19,999'
#  '$7,000 to $9,999' '$90,000 to $119,999' '$5,000 to $6,999'
#  '$35,000 to $39,999' '$120,000 to $159,999' "I don't want to answer"
#  '$200,000 to $249,999' '$250,000 or over' 'I don’t know'
#  '$160,000 to $199,999']

# %%
df_clean= df_clean[df_clean["Income"] != 'I don’t know']
print(df_clean["Income"].unique())
# Out:
# ['Under $1,000' '$40,000 to $49,999' '$75,000 to $89,999'
#  '$60,000 to $74,999' '$1,000 to $2,999' '$10,000 to $14,999'
#  '$20,000 to $24,999' '$25,000 to $29,999' '$30,000 to $34,999'
#  '$3,000 to $4,999' '$50,000 to $59,999' '$15,000 to $19,999'
#  '$7,000 to $9,999' '$90,000 to $119,999' '$5,000 to $6,999'
#  '$35,000 to $39,999' '$120,000 to $159,999' "I don't want to answer"
#  '$200,000 to $249,999' '$250,000 or over' '$160,000 to $199,999']

# %%
df_clean = df_clean[df_clean["Income"] != "I don't want to answer"]
print(df_clean["Income"].unique())
# Out:
# ['Under $1,000' '$40,000 to $49,999' '$75,000 to $89,999'
#  '$60,000 to $74,999' '$1,000 to $2,999' '$10,000 to $14,999'
#  '$20,000 to $24,999' '$25,000 to $29,999' '$30,000 to $34,999'
#  '$3,000 to $4,999' '$50,000 to $59,999' '$15,000 to $19,999'
#  '$7,000 to $9,999' '$90,000 to $119,999' '$5,000 to $6,999'
#  '$35,000 to $39,999' '$120,000 to $159,999' '$200,000 to $249,999'
#  '$250,000 or over' '$160,000 to $199,999']

# %%
df_clean = df_clean[df_clean["Income"] != "None"]
print(df_clean["Income"].unique())
# Out:
# ['Under $1,000' '$40,000 to $49,999' '$75,000 to $89,999'
#  '$60,000 to $74,999' '$1,000 to $2,999' '$10,000 to $14,999'
#  '$20,000 to $24,999' '$25,000 to $29,999' '$30,000 to $34,999'
#  '$3,000 to $4,999' '$50,000 to $59,999' '$15,000 to $19,999'
#  '$7,000 to $9,999' '$90,000 to $119,999' '$5,000 to $6,999'
#  '$35,000 to $39,999' '$120,000 to $159,999' '$200,000 to $249,999'
#  '$250,000 or over' '$160,000 to $199,999']

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9205 entries, 1 to 18125
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Developer  9205 non-null   object
#  1   Age        9205 non-null   float64
#  2   Gender     9205 non-null   object
#  3   Area       9205 non-null   object
#  4   Immigrant  9205 non-null   object
#  5   English    9205 non-null   object
#  6   Education  9205 non-null   object
#  7   Income     9205 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 647.2+ KB

# %%
missing=round((df_clean.isnull().sum()/df_clean.shape[0])*100,2)
print(missing)
# Out:
# Developer    0.0
# Age          0.0
# Gender       0.0
# Area         0.0
# Immigrant    0.0
# English      0.0
# Education    0.0
# Income       0.0
# dtype: float64

# %%
from sklearn.preprocessing import OrdinalEncoder
income_level_order = [[
                       'Under $1,000',
                       '$1,000 to $2,999',
                       '$3,000 to $4,999',
                       '$5,000 to $6,999', 
                       '$7,000 to $9,999',
                       '$10,000 to $14,999',
                       '$15,000 to $19,999',
                       '$20,000 to $24,999',
                       '$25,000 to $29,999',
                       '$30,000 to $34,999', 
                       '$35,000 to $39,999',
                       '$40,000 to $49,999',
                       '$50,000 to $59,999',
                       '$60,000 to $74,999',
                       '$75,000 to $89,999',
                       '$90,000 to $119,999',
                       '$120,000 to $159,999',
                       '$160,000 to $199,999', 
                       '$200,000 to $249,999',
                       '$250,000 or over',]] 
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories = income_level_order)  
df_clean['IncomeLevel'] = encoder.fit_transform(df_clean[['Income']])
display(df_clean)
# Out:
#       Developer   Age Gender                         Area Immigrant English  \
# 1            No  38.0   Male  Latin America and Caribbean        No     Yes
# 4           Yes  35.0   Male        East Asia and Pacific        No     Yes
# 5           Yes  27.0   Male                North America        No      No
# 6           Yes  24.0   Male                North America        No      No
# 7           Yes  23.0   Male      Europe and Central Asia       Yes      No
# ...         ...   ...    ...                          ...       ...     ...
# 18119        No  32.0   Male      Europe and Central Asia       Yes      No
# 18120        No  37.0   Male      Europe and Central Asia       Yes     Yes
# 18123        No  23.0   Male                North America        No      No
# 18124       Yes  34.0   Male      Europe and Central Asia        No     Yes
# 18125        No  44.0   Male      Europe and Central Asia        No     Yes
#
# ...

# %%
sns.countplot(y = 'Income', data = df_clean)
# Out:
# <Axes: xlabel='count', ylabel='Income'>

# %%
df_clean['HighIncome'] = df_clean['IncomeLevel'].apply(lambda x:0 if x < 9 else 1)
df_clean.head()
# Out:
#   Developer   Age Gender                         Area Immigrant English  \
# 1        No  38.0   Male  Latin America and Caribbean        No     Yes
# 4       Yes  35.0   Male        East Asia and Pacific        No     Yes
# 5       Yes  27.0   Male                North America        No      No
# 6       Yes  24.0   Male                North America        No      No
# 7       Yes  23.0   Male      Europe and Central Asia       Yes      No
#
#                         Education              Income  IncomeLevel  HighIncome
# 1               Bachelor’s degree        Under $1,000          0.0           0
# 4               Bachelor’s degree  $40,000 to $49,999         11.0           1
# 5               Bachelor’s degree  $75,000 to $89,999         14.0           1
# 6  Some college credit, no degree  $60,000 to $74,999         13.0           1
# 7               Bachelor’s degree    $1,000 to $2,999          1.0           0

# %%
sns.countplot(y='HighIncome', data=df_clean)
# Out:
# <Axes: xlabel='count', ylabel='HighIncome'>

# %%
sns.countplot(y='Area', data=df_clean)
# Out:
# <Axes: xlabel='count', ylabel='Area'>

# %%
sns.boxplot(x =df_clean['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df_clean.drop(df_clean[(df_clean['Age'] < 13.0) | (df_clean['Age'] > 80.0)].index, inplace=True)

# %%
sns.boxplot(x =df_clean['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
plt.xlabel('Age')
plt.ylabel('People')
plt.xlim(0, 80)
plt.hist(df_clean['Age'],bins=10)
plt.show()

# %%
citizenship_counts = df_clean['Immigrant'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(citizenship_counts, labels=citizenship_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Are you an immigrant?')
plt.axis('equal')
plt.show()

# %%
education_counts = df_clean["Education"].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(education_counts, labels=education_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Education Levels')
plt.axis('equal')
plt.show()

# %%
sns.scatterplot( x="Age", y='Education', data=df_clean,hue='Education', size=15)
 
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
sns.countplot(y='Developer', data=df_clean)
# Out:
# <Axes: xlabel='count', ylabel='Developer'>

# %%
pd.crosstab(df_clean['Gender'],df_clean['Developer'])
# Out:
# Developer    No   Yes
# Gender
# Female     2199   247
# Male       5691  1064

# %%
print("Percentage of developers from female respondents:",round((247/2199)*100),"%")
print("Percentage of developers from female respondents:",round((1064/5691)*100),"%")
# Out:
# Percentage of developers from female respondents: 11 %
# Percentage of developers from female respondents: 19 %

# %%
sns.countplot(x=df_clean['English'])
# Out:
# <Axes: xlabel='English', ylabel='count'>

# %%
english_counts = df_clean["English"].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(english_counts, labels=english_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Is English your second language?')
plt.axis('equal')
plt.show()

# %%
sns.countplot(y='Gender', data=df_clean)
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
gender_counts = df_clean["Gender"].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender')
plt.axis('equal')
plt.show()

# %%
sns.boxplot( x="Age", y='Gender', data=df_clean, )
plt.show()

# %%
df_clean.head()
# Out:
#   Developer   Age Gender                         Area Immigrant English  \
# 1        No  38.0   Male  Latin America and Caribbean        No     Yes
# 4       Yes  35.0   Male        East Asia and Pacific        No     Yes
# 5       Yes  27.0   Male                North America        No      No
# 6       Yes  24.0   Male                North America        No      No
# 7       Yes  23.0   Male      Europe and Central Asia       Yes      No
#
#                         Education              Income  IncomeLevel  HighIncome
# 1               Bachelor’s degree        Under $1,000          0.0           0
# 4               Bachelor’s degree  $40,000 to $49,999         11.0           1
# 5               Bachelor’s degree  $75,000 to $89,999         14.0           1
# 6  Some college credit, no degree  $60,000 to $74,999         13.0           1
# 7               Bachelor’s degree    $1,000 to $2,999          1.0           0

# %%
X = df_clean[['Developer','Age','Gender','Area','Immigrant','English']]
X.head()
# Out:
#   Developer   Age Gender                         Area Immigrant English
# 1        No  38.0   Male  Latin America and Caribbean        No     Yes
# 4       Yes  35.0   Male        East Asia and Pacific        No     Yes
# 5       Yes  27.0   Male                North America        No      No
# 6       Yes  24.0   Male                North America        No      No
# 7       Yes  23.0   Male      Europe and Central Asia       Yes      No

# %%
y = df_clean[['HighIncome']]
y.head()
# Out:
#    HighIncome
# 1           0
# 4           1
# 5           1
# 6           1
# 7           0

# %%
education_level_order=[[
    'No high school (secondary school)',
    'Some high school',
    'High school diploma or equivalent (GED)',
    'Some college credit, no degree',
    'Associate’s degree',
    'Bachelor’s degree',
    "Master's degree (non-professional)",
    'Professional degree (MBA, MD, JD, etc.)',
    'Ph.D.',
    'Trade, technical, or vocational training'
]]
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories = education_level_order)
X['EducationLevel'] = encoder.fit_transform(df_clean[['Education']])
display(X)
# Out:
#       Developer   Age Gender                         Area Immigrant English  \
# 1            No  38.0   Male  Latin America and Caribbean        No     Yes
# 4           Yes  35.0   Male        East Asia and Pacific        No     Yes
# 5           Yes  27.0   Male                North America        No      No
# 6           Yes  24.0   Male                North America        No      No
# 7           Yes  23.0   Male      Europe and Central Asia       Yes      No
# ...         ...   ...    ...                          ...       ...     ...
# 18119        No  32.0   Male      Europe and Central Asia       Yes      No
# 18120        No  37.0   Male      Europe and Central Asia       Yes     Yes
# 18123        No  23.0   Male                North America        No      No
# 18124       Yes  34.0   Male      Europe and Central Asia        No     Yes
# 18125        No  44.0   Male      Europe and Central Asia        No     Yes
#
#        EducationLevel
# 1                 5.0
# ...

# %%
X = pd.get_dummies(X) 
X.head()
# Out:
#     Age  EducationLevel  Developer_No  Developer_Yes  Gender_Female  \
# 1  38.0             5.0          True          False          False
# 4  35.0             5.0         False           True          False
# 5  27.0             5.0         False           True          False
# 6  24.0             3.0         False           True          False
# 7  23.0             5.0         False           True          False
#
#    Gender_Male  Area_East Asia and Pacific  Area_Europe and Central Asia  \
# 1         True                       False                         False
# 4         True                        True                         False
# 5         True                       False                         False
# 6         True                       False                         False
# 7         True                       False                          True
#
#    Area_Latin America and Caribbean  Area_Middle East and North Africa  \
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) 
print(X_train[0:5])
# Out:
#         Age  EducationLevel  Developer_No  Developer_Yes  Gender_Female  \
# 7964   52.0             3.0          True          False          False
# 8662   23.0             5.0          True          False          False
# 16304  42.0             5.0          True          False          False
# 6079   24.0             5.0          True          False           True
# 12867  30.0             7.0          True          False          False
#
#        Gender_Male  Area_East Asia and Pacific  Area_Europe and Central Asia  \
# 7964          True                       False                         False
# 8662          True                       False                         False
# 16304         True                        True                         False
# 6079         False                       False                         False
# 12867         True                       False                         False
#
# ...

# %%
from sklearn import tree 
from sklearn import metrics 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,ConfusionMatrixDisplay, roc_curve, auc
#model1= tree.DecisionTreeClassifier()
model1 = tree.DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=5, min_samples_split=20, min_samples_leaf=20, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0)  #build a decision tree

# %%
model1 = model1.fit(X_train, y_train) #fit decision tree

# %%
y_pred = model1.predict(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':["gini","entropy"],
'max_depth': [2, 3, 4, 5],
'min_samples_leaf': [10, 20, 30],
'min_samples_split': [20, 30, 40]}

clf = DecisionTreeClassifier()

grid_search = GridSearchCV(clf, param_grid, cv=5)

grid_search.fit(X_train, y_train)

print("Best hyperparameters: ", grid_search.best_params_)
# Out:
# Best hyperparameters:  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}

# %%
Accuracy = metrics.accuracy_score(y_test, y_pred) 
print ("Accuracy: ", Accuracy)
# Out:
# Accuracy:  0.8004346251358203

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1858
#            1       0.69      0.70      0.70       903
#
#     accuracy                           0.80      2761
#    macro avg       0.77      0.78      0.77      2761
# weighted avg       0.80      0.80      0.80      2761

# %%
from sklearn.tree import export_graphviz
import graphviz

export_graphviz(model1, out_file='tree.dot', 
                feature_names=X.columns,  
                class_names=["Low", "High"],  
                filled=True, rounded=True,  
                special_characters=True)

# Read the exported .dot file and render it as a Graphviz object
with open("tree.dot") as f:
    dot_data = f.read()
graph = graphviz.Source(dot_data)

# Display the decision tree
display(graph)

# %%
cm1 = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm1,display_labels=model1.classes_)
disp.plot()

# %%
y_prob = model1.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
 
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve\nAccuracy: {:.2f}%'.format(
    accuracy * 100))
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 12
#       9 plt.xlabel('False Positive Rate')
#      10 plt.ylabel('True Positive Rate')
#      11 plt.title('Receiver Operating Characteristic (ROC) Curve\nAccuracy: {:.2f}%'.format(
# ---> 12     accuracy * 100))
#      13 plt.legend(loc="lower right")
#      14 plt.show()
#
# NameError: name 'accuracy' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=450,max_depth=7)
rf.fit(X_train, y_train)

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %%
for i in range(3):
    tree = rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=2, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV
param_dist = {'n_estimators': randint(50,500),
              'max_depth': randint(1,20)}

# Create a random forest classifier
rf = RandomForestClassifier()

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(rf, 
                                 param_distributions = param_dist, 
                                 n_iter=5, 
                                 cv=5)

rand_search.fit(X_train, y_train)

# %%
best_rf = rand_search.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)

# %%
cmRF = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cmRF,display_labels=rf.classes_)
disp.plot()

# %%
y_prob = rf.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
 
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve\nAccuracy: {:.2f}%'.format(
    accuracy * 100))
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.preprocessing import StandardScaler  # Import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model2 = KNeighborsClassifier(n_neighbors = 16)  

model2.fit(X_train,y_train)

predict_train = model2.predict(X_train)

# %%
from sklearn.metrics import recall_score, precision_score
y_pred = model2.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %%
from sklearn import metrics
acc = []
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(X_train,y_train)
    yhat = neigh.predict(X_test)
    acc.append(metrics.accuracy_score(y_test, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:",max(acc),"at K =",acc.index(max(acc)))

# %%
cm2 = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm1,display_labels=model2.classes_)
disp.plot()

# %%
y_prob = model2.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
 
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve\nAccuracy: {:.2f}%'.format(
    accuracy * 100))
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler  

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model3 = LogisticRegression()
model3.fit(X_train, y_train)
y_pred = model3.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %%
cm3=confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm3,display_labels=model3.classes_)
disp.plot()

# %%
y_prob = model3.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
 
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve\nAccuracy: {:.2f}%'.format(
    accuracy * 100))
plt.legend(loc="lower right")
plt.show()

# %%
df_cluster = df_clean[['Developer','Age','Gender','Area','Immigrant','English','Education','HighIncome']]
df_cluster.head()

# %%
high_income_group = df_cluster[df_cluster['HighIncome'] == 1]
low_income_group = df_cluster[df_cluster['HighIncome'] == 0]

# %%
X = high_income_group[['Developer','Age','Gender','Area','Immigrant','English','Education']]
X.head()

# %%
y = high_income_group[['HighIncome']]
y.head()

# %%
X = pd.get_dummies(X) 
X.head()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()

visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)
visualizer.show()

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4)

# %%
y_cluster = km.fit_predict(X)
print(y_cluster[0:5])
high_income_group['ClusterLabel'] = y_cluster 
high_income_group.head()

# %%
sns.countplot(data=high_income_group, x="ClusterLabel", hue="Gender")

# %%
sns.countplot(data=high_income_group, x="ClusterLabel", hue="Area")

# %%
sns.countplot(data=high_income_group, x="ClusterLabel", hue="Education")

# %%
X = low_income_group[['Developer','Age','Gender','Area','Immigrant','English','Education']]
X.head()

# %%
y =low_income_group[['HighIncome']]
y.head()

# %%
X = pd.get_dummies(X) 
X.head()

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10))
visualizer.fit(X)
visualizer.show()

# %%
km = KMeans(n_clusters=4)

# %%
y_cluster = km.fit_predict(X)
print(y_cluster[0:5])
low_income_group['ClusterLabel'] = y_cluster 
low_income_group.head()

# %%
sns.countplot(data=low_income_group, x="ClusterLabel", hue="Gender")

# %%
sns.countplot(data=low_income_group, x="ClusterLabel", hue="Area")

# %%
sns.countplot(data=low_income_group, x="ClusterLabel", hue="Education")
